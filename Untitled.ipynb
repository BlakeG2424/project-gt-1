# %%
import requests
import json
import fred
url="https://api.stlouisfed.org/fred/series/search?search_text=monetary+service+index&api_key=d837251519348a565319f8cf14a42786&file_type=json"
response=requests.get(url)
response.json()

#fred="d837251519348a565319f8cf14a42786"
# Out:
# {'realtime_start': '2023-01-26',
#  'realtime_end': '2023-01-26',
#  'order_by': 'search_rank',
#  'sort_order': 'desc',
#  'count': 885,
#  'offset': 0,
#  'limit': 1000,
#  'seriess': [{'id': 'MSIM2',
#    'realtime_start': '2023-01-26',
#    'realtime_end': '2023-01-26',
#    'title': 'Monetary Services Index: M2 (preferred)',
#    'observation_start': '1967-01-01',
#    'observation_end': '2013-12-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Billions of Dollars',
#    'units_short': 'Bil. of $',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2014-01-17 07:16:44-06',
#    'popularity': 25,
#    'group_popularity': 25,
# ...
