# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd


# Study data files
russia_alcohol = "Data/russia_alcohol.csv"
unemployment_data = "Data/unemployment_data.csv"

# Read CSV
alc_df = pd.read_csv(russia_alcohol)
unemp_df = pd.read_csv(unemployment_data)
alc_df.head(30)
# Out:
#     year                      region  wine  beer  vodka  champagne  brandy
# 0   1998          Republic of Adygea   1.9   8.8    3.4        0.3    0.10
# 1   1998                  Altai Krai   3.3  19.2   11.3        1.1    0.10
# 2   1998                 Amur Oblast   2.1  21.2   17.3        0.7    0.40
# 3   1998          Arkhangelsk Oblast   4.3  10.6   11.7        0.4    0.30
# 4   1998            Astrakhan Oblast   2.9  18.0    9.5        0.8    0.20
# 5   1998   Republic of Bashkortostan   1.8  17.5   10.7        0.9    0.20
# 6   1998             Belgorod Oblast   3.4  23.0   10.8        0.9    0.10
# 7   1998              Bryansk Oblast   3.4  32.4    9.7        0.5    0.10
# 8   1998        Republic of Buryatia   1.1   8.8   15.8        0.9    0.10
# 9   1998             Vladimir Oblast   1.5  16.6   16.8        0.5    0.10
# 10  1998            Volgograd Oblast   2.9  27.9   12.9        1.5    0.30
# 11  1998              Vologda Oblast   3.9  23.7   19.3        0.6    0.30
# 12  1998             Voronezh Oblast   1.3  19.0   14.2        1.2    0.10
# 13  1998        Republic of Dagestan   4.8   3.8    2.0        0.5    0.30
# 14  1998    Jewish Autonomous Oblast   2.3  11.6   11.5        0.5    0.20
# 15  1998            Zabaykalsky Krai   0.9   8.6    5.0        0.2    0.10
# 16  1998              Ivanovo Oblast   1.4  20.7   16.1        0.1    0.04
# 17  1998      Republic of Ingushetia   NaN   NaN    NaN        NaN     NaN
# 18  1998              Irkutsk Oblast   5.6  26.8   14.8        1.0    0.40
# 19  1998   Kabardino-Balkar Republic   1.6   9.9    6.5        0.3    0.30
# 20  1998          Kaliningrad Oblast   2.7  21.6   12.2        1.1    0.30
# 21  1998        Republic of Kalmykia   2.3   4.1   11.1        0.3    0.10
# 22  1998               Kaluga Oblast   2.8  24.2   15.6        0.7    0.10
# 23  1998              Kamchatka Krai   6.4  25.5   25.1        0.8    0.40
# 24  1998  Karachay-Cherkess Republic   1.7   5.4    8.6        0.1    0.04
# 25  1998         Republic of Karelia   3.2  16.2   15.4        0.5    0.20
# 26  1998             Kemerovo Oblast   3.6  25.6   16.8        1.1    0.40
# 27  1998                Kirov Oblast   2.0  12.4   12.8        0.4    0.10
# 28  1998             Kostroma Oblast   1.7  25.8   17.9        1.2    0.10
# 29  1998              Krasnodar Krai   8.5  18.3    8.7        1.0    0.30

# %%
# cleaning data
# renaming column and averaging months into year
# Study data files
clean_unemp = unemp_df.rename(columns={"LMUNRRTTRUM156S": "Max Unemployment Rate"})

clean_unemp = clean_unemp.groupby(pd.PeriodIndex(clean_unemp['DATE'], freq="Y"))['Max Unemployment Rate'].max()

# change null values to 0
clean_alc = alc_df.dropna()
# add in a total per region
clean_alc["Total"] = clean_alc["wine"] + clean_alc["beer"] + clean_alc["vodka"] + clean_alc["champagne"] + clean_alc["brandy"]
clean_alc

# make a new df for total russian consumption
# Out:
# /var/folders/89/wrvs6qkx5jzf1gpgxwy68q1h0000gp/T/ipykernel_54735/3590815292.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_alc["Total"] = clean_alc["wine"] + clean_alc["beer"] + clean_alc["vodka"] + clean_alc["champagne"] + clean_alc["brandy"]
#       year                          region  wine  beer  vodka  champagne  \
# 0     1998              Republic of Adygea   1.9   8.8    3.4        0.3
# 1     1998                      Altai Krai   3.3  19.2   11.3        1.1
# 2     1998                     Amur Oblast   2.1  21.2   17.3        0.7
# 3     1998              Arkhangelsk Oblast   4.3  10.6   11.7        0.4
# 4     1998                Astrakhan Oblast   2.9  18.0    9.5        0.8
# ...    ...                             ...   ...   ...    ...        ...
# 1610  2016                Chuvash Republic   5.0  42.3    7.7        0.7
# 1611  2016       Chukotka Autonomous Okrug   3.9  34.0   11.6        1.8
# 1612  2016        Sakha (Yakutia) Republic   4.3  56.1    8.2        1.8
# 1613  2016  Yamalo-Nenets Autonomous Okrug   4.5  75.8    8.2        1.7
# 1614  2016                Yaroslavl Oblast  10.2  38.0    8.9        1.4
#
#       brandy  Total
# 0        0.1   14.5
# 1        0.1   35.0
# 2        0.4   41.7
# 3        0.3   27.3
# 4        0.2   31.4
# ...      ...    ...
# 1610     0.4   56.1
# 1611     1.1   52.4
# 1612     0.5   70.9
# 1613     1.3   91.5
# 1614     1.0   59.5
#
# [1549 rows x 8 columns]

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
